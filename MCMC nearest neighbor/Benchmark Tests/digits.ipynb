# %%
import sys 
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import pprint

# ml imports
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_digits

#pytorch imports
from torchvision import transforms
from torchvision import datasets
import torch
from torch.utils.data import DataLoader
from torch import nn
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import Dataset, random_split
from torchvision.transforms import ToTensor

sys.path.append("../")
from experimenter import *

# %% [markdown]
# # Load Datasets

# %%
#digits dataset
digits_X, digits_y = load_digits(return_X_y=True)


#fashion dataset
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
# split data
test_size = 0.2
train_size = 1 - test_size
random_state = 42
X_train, X_test, y_train, y_test = train_test_split(digits_X, digits_y, test_size=test_size, random_state=random_state, shuffle=True)

print("X shape: ", X_train.shape)
print("y shape: ", y_train.shape)
# Out:
# X shape:  (1437, 64)
# y shape:  (1437,)

# %% [markdown]
# # Global Variables

# %%
# customize based on training data
dataset_name = "Digits"
data_sizes = [20, 50, 100, 200, 455]
datetime = dt.datetime.now().strftime(date_format)
experiment_info = (dataset_name, data_sizes, X_train, y_train, X_test, y_test)
constants = (data_sizes, datetime, dataset_name)
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# # Model Training

# %%
# RANDOM FOREST
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'randomforest'

rfr_results = benchmark_ml(model_name, experiment_info, datetime)
benchmarking.update(rfr_results)
# Out:
# Benchmarking randomforest:  24%|████             | 6/25 [00:01<00:03,  4.96it/s]
# Made a new directory results/Digits/randomforest/npy_files
# Benchmarking randomforest: 100%|████████████████| 25/25 [00:04<00:00,  5.01it/s]

# %%
# K NEAREST NEIGHBORS
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'knn'

knn_results = benchmark_ml(model_name, experiment_info, datetime)
benchmarking.update(knn_results)
# Out:
# Benchmarking knn:  36%|█████████▎                | 9/25 [00:00<00:00, 28.29it/s]
# Made a new directory results/Digits/knn/npy_files
# Benchmarking knn: 100%|█████████████████████████| 25/25 [00:00<00:00, 25.43it/s]

# %%
# CONVULUTIONAL NEURAL NETWORK
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'cnn'

# %%
# METRIC LEARNING
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'metric'

# %%
# OUR MODEL
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'ours'

# our_results = benchmark_ml(model_name, experiment_info, datetime)
# benchmarking.update(our_results)

# %% [markdown]
# # Model Evaluation

# %%
plot_results(benchmarking, constants, 
             save_fig=True, 
             from_data=False)

# %%
# pretty print the benchmarking results with package
pp.pprint(benchmarking)
# Out:
# {   'knn': {   0: {   'time': array([0.00200717, 0.00059458, 0.00034804, 0.00034096, 0.00039571]),
#                       'train_acc': array([0.6       , 0.84      , 0.97      , 0.975     , 0.98901099]),
#                       'val_acc': array([0.33888889, 0.72222222, 0.91388889, 0.94722222, 0.96666667])},
#                1: {   'time': array([0.00042942, 0.00034429, 0.00034721, 0.00035613, 0.00076267]),
#                       'train_acc': array([0.6       , 0.84      , 0.97      , 0.975     , 0.98901099]),
#                       'val_acc': array([0.33888889, 0.72222222, 0.91388889, 0.94722222, 0.96666667])},
#                2: {   'time': array([0.00038421, 0.00033796, 0.00037279, 0.000687  , 0.00048329]),
#                       'train_acc': array([0.6       , 0.84      , 0.97      , 0.975     , 0.98901099]),
#                       'val_acc': array([0.33888889, 0.72222222, 0.91388889, 0.94722222, 0.96666667])},
#                3: {   'time': array([0.00053308, 0.00072867, 0.00059313, 0.000541  , 0.00082779]),
#                       'train_acc': array([0.6       , 0.84      , 0.97      , 0.975     , 0.98901099]),
#                       'val_acc': array([0.33888889, 0.72222222, 0.91388889, 0.94722222, 0.96666667])},
#                4: {   'time': array([0.00052483, 0.00046908, 0.000663  , 0.00042663, 0.00045792]),
#                       'train_acc': array([0.6       , 0.84      , 0.97      , 0.975     , 0.98901099]),
#                       'val_acc': array([0.33888889, 0.72222222, 0.91388889, 0.94722222, 0.96666667])},
#                'mean': {   'time': array([0.00077574, 0.00049492, 0.00046483, 0.00047034, 0.00058547]),
#                            'train_acc': array([0.6       , 0.84      , 0.97      , 0.975     , 0.98901099]),
#                            'val_acc': array([0.33888889, 0.72222222, 0.91388889, 0.94722222, 0.96666667])},
#                'std': {   'time': array([0.0006183 , 0.00015004, 0.00013541, 0.00012933, 0.00017484]),
#                           'train_acc': array([0.00000000e+00, 1.11022302e-16, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00]),
#                           'val_acc': array([0.00000000e+00, 0.00000000e+00, 1.11022302e-16, 0.00000000e+00,
#        1.11022302e-16])}},
#     'randomforest': {   0: {   'time': array([0.17500537, 0.14950704, 0.15186271, 0.15383317, 0.15817204]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.525     , 0.71944444, 0.90277778, 0.90833333, 0.96388889])},
#                         1: {   'time': array([0.14315783, 0.14534296, 0.14622487, 0.15166121, 0.157091  ]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.52777778, 0.7       , 0.88333333, 0.89722222, 0.97222222])},
#                         2: {   'time': array([0.14275888, 0.1442775 , 0.14580542, 0.15198471, 0.15550283]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.51111111, 0.68333333, 0.89166667, 0.89444444, 0.96944444])},
#                         3: {   'time': array([0.14357658, 0.14358542, 0.14373771, 0.15204679, 0.15833258]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.51111111, 0.7       , 0.90277778, 0.89444444, 0.96111111])},
#                         4: {   'time': array([0.14283563, 0.14452667, 0.14468567, 0.15280975, 0.15753525]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.49444444, 0.71111111, 0.89444444, 0.91388889, 0.96666667])},
#                         'mean': {   'time': array([0.14946686, 0.14544792, 0.14646327, 0.15246712, 0.15732674]),
#                                     'train_acc': array([1., 1., 1., 1., 1.]),
#                                     'val_acc': array([0.51388889, 0.70277778, 0.895     , 0.90166667, 0.96666667])},
#                         'std': {   'time': array([0.01277251, 0.00210594, 0.00283662, 0.00078005, 0.00101508]),
#                                    'train_acc': array([0., 0., 0., 0., 0.]),
#                                    'val_acc': array([0.01191534, 0.01217161, 0.00732828, 0.00797372, 0.00392837])}}}
