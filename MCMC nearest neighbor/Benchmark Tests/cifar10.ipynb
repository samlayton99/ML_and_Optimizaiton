# %%
import sys
import datetime as dt
import numpy as np
import pprint

from sklearn.model_selection import train_test_split

sys.path.append('../')
from experimenter import *

# %% [markdown]
# # Load Data
#
# source: https://www.cs.toronto.edu/~kriz/cifar.html
#
#
# Citation:
# Learning Multiple Layers of Features from Tiny Images, Alex Krizhevsky, 2009.
# https://www.cs.toronto.edu/~kriz/learning-features-2009-TR.pdf

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# load cifar dataset from files
batch1 = unpickle('../data/cifar-10-batches-py/data_batch_1')
X = batch1[b'data']
y = np.array(batch1[b'labels'])

# split data
test_size = 0.2
train_size = 1 - test_size
random_state = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state, shuffle=True)

print("X shape: ", X_train.shape)
print("y shape: ", y_train.shape)

# remember to do any preprocessing necessary for the data
# Out:
# X shape:  (8000, 3072)
# y shape:  (8000,)

# %% [markdown]
# ## Global Variables

# %%
# customize based on training data
dataset_name = "cifar10"
data_sizes = [50, 100, 500, 2000, 8000]
datetime = dt.datetime.now().strftime(date_format)
experiment_info = (dataset_name, data_sizes, X_train, y_train, X_test, y_test)
constants = (data_sizes, datetime, dataset_name)
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# # Model Training

# %%
# RANDOM FOREST
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'randomforest'

rfr_results = benchmark_ml(model_name, experiment_info, datetime)
benchmarking.update(rfr_results)
# Out:
# Benchmarking randomforest: 100%|██████████| 25/25 [01:50<00:00,  4.41s/it]

# %%
# K NEAREST NEIGHBORS
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'knn'

knn_results = benchmark_ml(model_name, experiment_info, datetime)
benchmarking.update(knn_results)
# Out:
# Benchmarking knn: 100%|██████████| 25/25 [01:58<00:00,  4.73s/it]

# %%
# CONVULUTIONAL NEURAL NETWORK
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'cnn'

# %%
# METRIC LEARNING
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'metric'

# %%
# OUR MODEL
new_set = False
if new_set:
    datetime = dt.datetime.now().strftime(date_format)
model_name = 'ours'

# our_results = benchmark_ml(model_name, experiment_info, datetime)
# benchmarking.update(our_results)

# %% [markdown]
# # Model Evaluation

# %%
plot_results(benchmarking, constants, 
             save_fig=True, 
             from_data=False)

# %%
# pretty print the benchmarking results with package
pp.pprint(benchmarking)
# Out:
# {   'knn': {   0: {   'time': array([0.0011849, 0.0007722, 0.0012264, 0.0019127, 0.0034688]),
#                       'train_acc': array([0.28   , 0.34   , 0.4    , 0.4255 , 0.46125]),
#                       'val_acc': array([0.163, 0.171, 0.222, 0.247, 0.284])},
#                1: {   'time': array([0.0034777, 0.0016011, 0.0014321, 0.0021586, 0.0032445]),
#                       'train_acc': array([0.28   , 0.34   , 0.4    , 0.4255 , 0.46125]),
#                       'val_acc': array([0.163, 0.171, 0.222, 0.247, 0.284])},
#                2: {   'time': array([0.0012651, 0.0011988, 0.0027327, 0.0021037, 0.0026606]),
#                       'train_acc': array([0.28   , 0.34   , 0.4    , 0.4255 , 0.46125]),
#                       'val_acc': array([0.163, 0.171, 0.222, 0.247, 0.284])},
#                3: {   'time': array([0.0012859, 0.0011739, 0.0013342, 0.0015623, 0.0019572]),
#                       'train_acc': array([0.28   , 0.34   , 0.4    , 0.4255 , 0.46125]),
#                       'val_acc': array([0.163, 0.171, 0.222, 0.247, 0.284])},
#                4: {   'time': array([0.000752 , 0.0012785, 0.000961 , 0.0016784, 0.0027004]),
#                       'train_acc': array([0.28   , 0.34   , 0.4    , 0.4255 , 0.46125]),
#                       'val_acc': array([0.163, 0.171, 0.222, 0.247, 0.284])},
#                'mean': {   'time': array([0.00159312, 0.0012049 , 0.00153728, 0.00188314, 0.0028063 ]),
#                            'train_acc': array([0.28   , 0.34   , 0.4    , 0.4255 , 0.46125]),
#                            'val_acc': array([0.163, 0.171, 0.222, 0.247, 0.284])},
#                'std': {   'time': array([0.00096206, 0.00026481, 0.00061807, 0.00023249, 0.00052618]),
#                           'train_acc': array([0., 0., 0., 0., 0.]),
#                           'val_acc': array([0.00000000e+00, 0.00000000e+00, 2.77555756e-17, 2.77555756e-17,
#        0.00000000e+00])}},
#     'randomforest': {   0: {   'time': array([ 0.2435834,  0.2475068,  0.6879273,  3.7292324, 15.7712454]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.1885, 0.239 , 0.33  , 0.3815, 0.4255])},
#                         1: {   'time': array([ 0.2673053,  0.2545136,  0.8434532,  3.4642201, 15.5402944]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.1955, 0.216 , 0.3095, 0.374 , 0.433 ])},
#                         2: {   'time': array([ 0.2673339,  0.2618669,  0.7358433,  3.4506514, 15.8420883]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.1985, 0.2315, 0.3235, 0.3815, 0.426 ])},
#                         3: {   'time': array([ 0.331741 ,  0.3422766,  0.8696107,  3.5782247, 15.8145505]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.192 , 0.234 , 0.3235, 0.374 , 0.414 ])},
#                         4: {   'time': array([ 0.2916851,  0.2674653,  0.7219106,  3.5122101, 16.2270475]),
#                                'train_acc': array([1., 1., 1., 1., 1.]),
#                                'val_acc': array([0.196 , 0.242 , 0.336 , 0.368 , 0.4125])},
#                         'mean': {   'time': array([ 0.28032974,  0.27472584,  0.77174902,  3.54690774, 15.83904522]),
#                                     'train_acc': array([1., 1., 1., 1., 1.]),
#                                     'val_acc': array([0.1941, 0.2325, 0.3245, 0.3758, 0.4222])},
#                         'std': {   'time': array([0.02986933, 0.03444005, 0.07143888, 0.10151797, 0.22136119]),
#                                    'train_acc': array([0., 0., 0., 0., 0.]),
#                                    'val_acc': array([0.00348425, 0.00903327, 0.0088261 , 0.00514393, 0.00778845])}}}
